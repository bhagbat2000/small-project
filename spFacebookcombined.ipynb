# %%
import networkx as nx
import numpy



G=nx.read_edgelist("facebook_combined.txt")
N=list(G.nodes())


spll=[]

for u in N:
    for v in N:
        if u!=v:
            l=nx.shortest_path_length(G,u,v)
            print("Shortest path between ",u," and ",v,"is of length",l)
            spll.append(l)
            
min_spl=min(spll)
max_spl=max(spll)
avg_spl=numpy.average(spll)
print("Minimum shortest path length:",min_spl)
print("Maxmum shortest path length:",max_spl)
print("average shortest path length:",avg_spl)
# Out:
# Shortest path between  0  and  1 is of length 1
# Shortest path between  0  and  2 is of length 1
# Shortest path between  0  and  3 is of length 1
# Shortest path between  0  and  4 is of length 1
# Shortest path between  0  and  5 is of length 1
# Shortest path between  0  and  6 is of length 1
# Shortest path between  0  and  7 is of length 1
# Shortest path between  0  and  8 is of length 1
# Shortest path between  0  and  9 is of length 1
# Shortest path between  0  and  10 is of length 1
# Shortest path between  0  and  11 is of length 1
# Shortest path between  0  and  12 is of length 1
# Shortest path between  0  and  13 is of length 1
# Shortest path between  0  and  14 is of length 1
# Shortest path between  0  and  15 is of length 1
# Shortest path between  0  and  16 is of length 1
# Shortest path between  0  and  17 is of length 1
# Shortest path between  0  and  18 is of length 1
# Shortest path between  0  and  19 is of length 1
# ...
